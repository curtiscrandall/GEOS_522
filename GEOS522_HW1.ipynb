# %% [markdown]
# # Homework 1
# ## Data Analysis and Geostatistics, Fall 2018
#
#     Download the two snow depth data sets
#     Data is in centimeters
#
# The importance of knowing the basic statistical values(mean, std, distribution, etc.) becomes apparent as you run multiple variations of the same analysis on the same data. It can greatly affect the outcome probabilities.

# %%
# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
from scipy import stats
from scipy.stats import iqr, kurtosis, skew, norm

# %%
# Import depths1 into an array
df = pd.read_csv('depths1.txt', names=['Depth'])  # Import depth1.txt
depth1 = df.Depth.values                          # create an array of values from depths1.txt
df[0:5]                                           # check first 5 rows
# Out:
#         Depth
# 0  162.241390
# 1  164.809320
# 2   50.394533
# 3  236.964180
# 4  404.263640

# %%
# Import depths2 into an array
df2 = pd.read_csv('depths2.txt', names=['Depth'])  # Import depth2.txt
depth2 = df2.Depth.values                          # create an array of values from depths2.txt
df2[:5]                                            # check first 5 rows
# Out:
#        Depth
# 0  270.99288
# 1  271.05618
# 2  285.13731
# 3  256.98932
# 4  226.27401

# %%
# Combine both datasets into one, 2 column array
depthData = np.vstack((depth1,depth2))  # combine depth datasets into a single two column array
depthData[:5,:5]                        # check first 5 rows of both datasets
# Out:
# array([[ 162.24139 ,  164.80932 ,   50.394533,  236.96418 ,  404.26364 ],
#        [ 270.99288 ,  271.05618 ,  285.13731 ,  256.98932 ,  226.27401 ]])

# %% [markdown]
# ## 1. For each dataset, calculate and report the mean and standard deviation

# %% [markdown]
# ### Depth1 Data

# %%
d1Max = np.max(depth1)   # max
d1Min = np.min(depth1)   # min
d1men = np.mean(depth1)  # mean
d1men
# Out:
# 203.17704758895997

# %%
d1std = np.std(depth1)  # standard deviation
d1std
# Out:
# 69.834927104057869

# %% [markdown]
# ### Depth2 Data

# %%
d2Max = np.max(depth2)   # max
d2Min = np.min(depth2)   # min
d2men = np.mean(depth2)  # mean
d2men
# Out:
# 201.81157412000002

# %%
d2std = np.std(depth2)  # standard deviation
d2std
# Out:
# 72.995070142005574

# %% [markdown]
# ## 2. For each dataset, calculate and report the median, mode, IQR, skewness, and kurtosis

# %% [markdown]
# ### Depth1 Data

# %%
d1med = np.median(depth1)   # median
d1mod = stats.mode(depth1)  # mode; [0] index is mode value
d1iqr = iqr(depth1)         # IQR
d1skw = skew(depth1)        # skew
d1kur = kurtosis(depth1)    # kurtosis

# Print stat variables
print('---Sample Stats for Depth1---')
print('Median: %.2f' % d1med)
print('Mode: %.2f' % d1mod[0])
print('IQR: %.2f' % d1iqr)
print('Skew: %.2f' % d1skw)
print('Kurtosis: %.2f' % d1kur)
# Out:
# ---Sample Stats for Depth1---
# Median: 203.47
# Mode: 0.92
# IQR: 93.89
# Skew: 0.07
# Kurtosis: -0.06

# %% [markdown]
# ### Depth2 Data

# %%
d2med = np.median(depth2)   # median
d2mod = stats.mode(depth2)  # mode; [0] index is mode value
d2iqr = iqr(depth2)         # IQR
d2skw = skew(depth2)        # skew
d2kur = kurtosis(depth2)    # kurtosis

# Print stat variables
print('---Sample Stats for Depth2---')
print('Median: %.2f' % d2med)
print('Mode: %.2f' % d2mod[0])
print('IQR: %.2f' % d2iqr)
print('Skew: %.2f' % d2skw)
print('Kurtosis: %.2f' % d2kur)
# Out:
# ---Sample Stats for Depth2---
# Median: 188.70
# Mode: 101.85
# IQR: 143.04
# Skew: 0.05
# Kurtosis: -1.86

# %% [markdown]
# ## 3. For each dataset, create a notched boxplot

# %%
plt.figure(figsize=(20,10))                        # create a figure
plt.subplot(1,2,1)                                 # (nrows, ncols, index); create and assign subplot for depth1
plt.boxplot(depth1,1)                              # boxplot of depth1 values
plt.title('Notched Boxplot Depths1', fontsize=16)  # title for depth1 boxplot
plt.xlabel('x', fontsize=14)                       # x axis label for depth1 boxplot
plt.ylabel('Depth(cm)', fontsize=14)               # y axis label for depth1 boxplot

plt.subplot(1,2,2)                                 # create and assign subplot for depth2
plt.boxplot(depth2,1)                              # boxplot of depth2 values
plt.title('Notched Boxplot Depths2', fontsize=16)  # title for depth2 boxplot
plt.xlabel('x', fontsize=14)                       # x axis label for depth2 boxplot
plt.ylabel('Depth(cm)', fontsize=14)               # y axis label for depth2 boxplot

plt.show()                                         # show image plot

# %% [markdown]
# ## 4. Create a histogram for each dataset using 30 bins

# %%
plt.figure(figsize=(20,10))                  # create a figure
# Depth1
plt.subplot(1,2,1)                           # create and assign subplot for depth1
plt.hist(depth1,30)                          # 30 bin histogram of depth1 values
plt.title('Histogram Depths1', fontsize=16)  # title for depth1 histogram
plt.xlabel('Depth(cm)', fontsize=14)         # x axis label for depth1 histogram
plt.ylabel('Frequency', fontsize=14)         # y axis label for depth1 histogram
# Depth2
plt.subplot(1,2,2)                           # create and assign subplot for depth2
plt.hist(depth2,30)                          # 30 bin histogram of depth2 values
plt.title('Histogram Depths2', fontsize=16)  # title for depth2 histogram
plt.xlabel('Depth(cm)', fontsize=14)         # x axis label for depth2 histogram
plt.ylabel('Frequency', fontsize=14)         # y axis label for depth2 histogram
plt.show()                                   # show image plot

# %% [markdown]
# ## 5. Create one figure with all figure subplots

# %%
plt.figure(figsize=(20,20))                        # create a figure
plt.subplot(2,2,1)                                 # (nrows, ncols, index); create and assign subplot for depth1
plt.boxplot(depth1,1)                              # boxplot of depth1 values
plt.title('Notched Boxplot Depths1', fontsize=16)  # title for depth1 boxplot
plt.xlabel('x', fontsize=14)                       # x axis label for depth1 boxplot
plt.ylabel('Depth(cm)', fontsize=14)               # y axis label for depth1 boxplot
plt.subplot(2,2,2)                                 # (nrows, ncols, index); create and assign subplot for depth2
plt.boxplot(depth2,1)                              # boxplot of depth2 values
plt.title('Notched Boxplot Depths2', fontsize=16)  # title for depth2 boxplot
plt.xlabel('x', fontsize=14)                       # x axis label for depth2 boxplot
plt.ylabel('Depth(cm)', fontsize=14)               # y axis label for depth2 boxplot
plt.subplot(2,2,3)                                 # create and assign subplot for depth1
plt.hist(depth1,30)                                # 30 bin histogram of depth1 values
plt.title('Histogram Depths1', fontsize=16)        # title for depth1 histogram
plt.xlabel('Depth(cm)', fontsize=14)               # x axis label for depth1 histogram
plt.ylabel('Frequency', fontsize=14)               # y axis label for depth1 histogram
plt.subplot(2,2,4)                                 # create and assign subplot for depth2
plt.hist(depth2,30)                                # 30 bin histogram of depth2 values
plt.title('Histogram Depths2', fontsize=16)        # title for depth2 histogram
plt.xlabel('Depth(cm)', fontsize=14)               # x axis label for depth2 histogram
plt.ylabel('Frequency', fontsize=14)               # y axis label for depth2 histogram
plt.show()                                         # show image plot

# %% [markdown]
# ## 6. Set the axis limits to the same range of values

# %%
plt.figure(figsize=(20,20))                        # create a figure

plt.subplot(2,2,1)                                 # create and assign subplot for depth1
plt.xlim([0, 1])                                   # set x axis limits
plt.ylim([0, 475])                                 # set y axis limits
plt.boxplot(depth1,1)                              # boxplot of depth1 values
plt.title('Notched Boxplot Depths1', fontsize=16)  # title for depth1 boxplot
plt.xlabel('x', fontsize=14)                       # x axis label for depth1 boxplot
plt.ylabel('Depth(cm)', fontsize=14)               # y axis label for depth1 boxplot

plt.subplot(2,2,2)                                 # create and assign subplot for depth2
plt.xlim([0, 1])                                   # set x axis limits
plt.ylim([0, 475])                                 # set y axis limits
plt.boxplot(depth2,1)                              # boxplot of depth2 values
plt.title('Notched Boxplot Depths2', fontsize=16)  # title for depth2 boxplot
plt.xlabel('x', fontsize=14)                       # x axis label for depth2 boxplot
plt.ylabel('Depth(cm)', fontsize=14)               # y axis label for depth2 boxplot

plt.subplot(2,2,3)                                 # create and assign subplot for depth1
plt.xlim([0, 475])                                 # set x axis limits
plt.ylim([0, 300])                                 # set y axis limits
plt.hist(depth1,30)                                # 30 bin histogram of depth1 values
plt.title('Histogram Depths1', fontsize=16)        # title for depth1 histogram
plt.xlabel('Depth(cm)', fontsize=14)               # x axis label for depth1 histogram
plt.ylabel('Frequency', fontsize=14)               # y axis label for depth1 histogram

plt.subplot(2,2,4)                                 # create and assign subplot for depth2
plt.xlim([0, 475])                                 # set x axis limits
plt.ylim([0, 300])                                 # set y axis limits
plt.hist(depth2,30)                                # 30 bin histogram of depth2 values
plt.title('Histogram Depths2', fontsize=16)        # title for depth2 histogram
plt.xlabel('Depth(cm)', fontsize=14)               # x axis label for depth2 histogram
plt.ylabel('Frequency', fontsize=14)               # y axis label for depth2 histogram
plt.show()                                         # show image plot

# %% [markdown]
# ## 7. Create a Relative Density Histogram for both datasets

# %%
plt.figure(figsize=(20,10))                                   # create a figure
# Depth1
plt.subplot(1,2,1)                                            # create and assign subplot for depth1
plt.hist(depth1,bins=30, histtype='bar', normed=True)         # 30 bin histogram of normalized depth1 values
plt.title('Relative Density Histogram Depths1', fontsize=16)  # title for depth1 histogram
plt.xlabel('Depth(cm)', fontsize=14)                          # x axis label for depth1 histogram
plt.ylabel('Frequency', fontsize=14)                          # y axis label for depth1 histogram
# Depth2
plt.subplot(1,2,2)                                            # create and assign subplot for depth2
plt.hist(depth2,bins=30, histtype='bar', normed=True)         # 30 bin histogram of normalized depth2 values
plt.title('Relative Density Histogram Depths2', fontsize=16)  # title for depth2 histogram
plt.xlabel('Depth(cm)', fontsize=14)                          # x axis label for depth2 histogram
plt.ylabel('Frequency', fontsize=14)                          # y axis label for depth2 histogram
plt.show()                                                    # show image plot

# %% [markdown]
# ## 8. Use the previously calculated mean and standard deviation, calculate the normal distribution curve, and plot it on top of the histograms.

# %%
plt.figure(figsize=(20,10))                                             # create a figure

# Depth1
plt.subplot(1,2,1)                                                      # create and assign subplot for depth1
plt.hist(depth1,bins=30, histtype='bar', normed=True)                   # 30 bin histogram of depth1 values
d1Range = np.linspace(min(depth1), max(depth1), 100)                    # set a pseudo range limit for pdf line
plt.plot(d1Range, mlab.normpdf(d1Range, d1men, d1std),'r',linewidth=4)  # plot the pdf line of depth1 hist
plt.title('Relative Density Histogram Depths1', fontsize=16)            # title for depth1 histogram
plt.xlabel('Depth(cm)', fontsize=14)                                    # x axis label for depth1 histogram
plt.ylabel('Frequency', fontsize=14)                                    # y axis label for depth1 histogram

# Depth2
plt.subplot(1,2,2)                                                      # create and assign subplot for depth2
plt.hist(depth2,bins=30, histtype='bar', normed=True)                   # 30 bin histogram of depth2 values
d2Range = np.linspace(min(depth2), max(depth2), 100)                    # set a pseudo range limit for pdf line
plt.plot(d2Range, mlab.normpdf(d2Range, d2men, d2std),'r',linewidth=4)  # plot the pdf line of depth2 hist
plt.title('Relative Density Histogram Depths2', fontsize=16)            # title for depth2 histogram
plt.xlabel('Depth(cm)', fontsize=14)                                    # x axis label for depth2 histogram
plt.ylabel('Frequency', fontsize=14)                                    # y axis label for depth2 histogram

plt.show()                                                              # show image plot

# %% [markdown]
# ## Questions 9, 10, 11: What is the probability of...
# #### 9. a value will be within 20cm of the average value?
# #### 10. a value will be at least 20cm larger than the average value?
# #### 11. a value will be at least 20cm smaller than the average value?

# %%
plt.figure(figsize=(20,10))                              # create a figure
# Depth1
plt.subplot(1,2,1)                                       # create and assign subplot for depth1
plt.hist(depth1, bins=30, normed=True, cumulative=True)  # 30 bin histogram of depth1 values
plt.title('CDF Depths1', fontsize=16)                    # title for depth1 histogram
plt.xlabel('Depth(cm)', fontsize=14)                     # x axis label for depth1 histogram
plt.ylabel('Frequency', fontsize=14)                     # y axis label for depth1 histogram
# Depth2
plt.subplot(1,2,2)                                       # create and assign subplot for depth2
plt.hist(depth2, bins=30, normed=True, cumulative=True)  # 30 bin histogram of depth2 values
plt.title('CDF Depths2', fontsize=16)                    # title for depth2 histogram
plt.xlabel('Depth(cm)', fontsize=14)                     # x axis label for depth2 histogram
plt.ylabel('Frequency', fontsize=14)                     # y axis label for depth2 histogram

plt.show()                                               # show image plot

# %%
# QUESTION 9: WHAT IS THE PROBABILITY A VALUE WILL BE WITHIN 20CM OF THE AVERAGE VALUE?
# cdf(mean+20)-cdf(mean-20)
print('\033[1m'+'QUESTION 9: WHAT IS THE PROBABILITY A VALUE WILL BE WITHIN 20CM OF THE AVERAGE VALUE?')


print('\033[1m'+'*Rough/Basic Probabilities; ignoring distributions*')
# Depth1 values
lenD1 = len(depth1)                     # depth1 length
d1_mu20 = depth1[depth1 <= (d1men-20)]  # depth1 values that are <=mean-20
d1_20mu = depth1[depth1 <= (d1men+20)]  # depth1 values that are <=mean+20
d1_9a = len(d1_mu20) / len(depth1)      # probability of depth1 values <=mean-20
d1_9b = len(d1_20mu) / len(depth1)      # probability of depth1 values <=mean+20
d1_9c = (d1_9b - d1_9a)*100             # probability of depth1 values +/-20cm of mean
print('\033[0m'+'Depth1 value is within +/-20cm of mean: %.2f' % d1_9c)
# Depth1 values
lenD2 = len(depth2)                     # depth2 length
d2_mu20 = depth2[depth2 <= (d2men-20)]  # depth2 values that are <=mean-20
d2_20mu = depth2[depth2 <= (d2men+20)]  # depth2 values that are <=mean+20
d2_9a = len(d2_mu20) / len(depth2)      # probability of depth2 values <=mean-20
d2_9b = len(d2_20mu) / len(depth2)      # probability of depth2 values <=mean+20
d2_9c = (d2_9b - d2_9a)*100             # probability of depth2 values +/-20cm of mean
print('\033[0m'+'Depth2 value is within +/-20cm of mean: %.2f' % d2_9c)


print('\033[1m'+'*Probabilities calculated through built-in CDF libraries*')
# Depth 1
d1_mu20_p1 = norm.cdf(d1men+20, loc=d1men, scale=d1std)  # probability of mu+20
d1_mu20_p2 = norm.cdf(d1men-20, loc=d1men, scale=d1std)  # probability of mu-20
d1_p9 = (d1_mu20_p1 - d1_mu20_p2)*100                    # probability of value between mu+20 and mu-20
print('\033[0m'+'Depth1 value being within +/-20cm of mean: %.2f percent' % d1_p9)
# Depth 2
d2_mu20_p1 = norm.cdf(d2men+20, loc=d2men, scale=d2std)  # probability of mu+20
d2_mu20_p2 = norm.cdf(d2men-20, loc=d2men, scale=d2std)  # probability of mu-20
d2_p9 = (d2_mu20_p1 - d2_mu20_p2)*100                    # probability of value between mu+20 and mu-20
print('\033[0m'+'Depth2 value being within +/-20cm of mean: %.2f percent' % d2_p9)
# Out:
# QUESTION 9: WHAT IS THE PROBABILITY A VALUE WILL BE WITHIN 20CM OF THE AVERAGE VALUE?
# *Rough/Basic Probabilities; ignoring distributions*
# Depth1 value is within +/-20cm of mean: 21.30
# Depth2 value is within +/-20cm of mean: 0.10
# *Probabilities calculated through built-in CDF libraries*
# Depth1 value being within +/-20cm of mean: 22.54 percent
# Depth2 value being within +/-20cm of mean: 21.59 percent

# %%
# QUESTION 10: WHAT IS THE PROBABILITY A VALUE WILL BE AT LEAST 20CM ABOVE THE AVERAGE VALUE?
# cdf(max)-cdf(mean+20)
print('\033[1m'+'QUESTION 10: WHAT IS THE PROBABILITY A VALUE WILL BE AT LEAST 20CM ABOVE THE AVERAGE VALUE?')

print('\033[1m'+'*Probabilities calculated through built-in libraries*')
# Depth 1
d1_max_p1 = norm.cdf(d1Max, loc=d1men, scale=d1std)      # probability of max value
d1_mu20_p2 = norm.cdf(d1men+20, loc=d1men, scale=d1std)  # probability of mu+20
d1_p10 = (d1_max_p1 - d1_mu20_p2)*100                    # probability of value between mu+20 and mu-20
print('\033[0m'+'Probability of a Depth1 value being at least 20cm above the mean: %.2f percent' % d1_p10)
# Depth 2
d2_max_p1 = norm.cdf(d2Max, loc=d2men, scale=d2std)      # probability of max value
d2_mu20_p2 = norm.cdf(d2men+20, loc=d2men, scale=d2std)  # probability of mu+20
d2_p10 = (d2_max_p1 - d2_mu20_p2)*100                    # probability of value between mu+20 and mu-20
print('\033[0m'+'Probability of a Depth2 value being at least 20cm above the mean: %.2f percent' % d2_p10)
# Out:
# QUESTION 10: WHAT IS THE PROBABILITY A VALUE WILL BE AT LEAST 20CM ABOVE THE AVERAGE VALUE?
# *Probabilities calculated through built-in libraries*
# Probability of a Depth1 value being at least 20cm above the mean: 38.69 percent
# Probability of a Depth2 value being at least 20cm above the mean: 33.75 percent

# %%
# QUESTION 11: WHAT IS THE PROBABILITY A VALUE WILL BE AT LEAST 20CM BELOW THE AVERAGE VALUE?
# cdf(mean-20)-cdf(min)
print('\033[1m'+'QUESTION 11: WHAT IS THE PROBABILITY A VALUE WILL BE AT LEAST 20CM BELOW THE AVERAGE VALUE?')

print('\033[1m'+'*Probabilities calculated through built-in libraries*')
# Depth 1
d1_min_p1 = norm.cdf(d1Min, loc=d1men, scale=d1std)      # probability of min value
d1_mu20_p2 = norm.cdf(d1men-20, loc=d1men, scale=d1std)  # probability of mu+20
d1_p11 = (d1_mu20_p2 - d1_min_p1)*100                    # probability of value between mu-20 and min
print('\033[0m'+'Probability of a Depth1 value being at least 20cm below the mean: %.2f percent' % d1_p11)
# Depth 2
d2_min_p1 = norm.cdf(d2Min, loc=d2men, scale=d2std)      # probability of min value
d2_mu20_p2 = norm.cdf(d2men-20, loc=d2men, scale=d2std)  # probability of mu+20
d2_p11 = (d2_mu20_p2 - d2_min_p1)*100                    # probability of value between mu-20 and min
print('\033[0m'+'Probability of a Depth2 value being at least 20cm below the mean: %.2f percent' % d2_p11)
# Out:
# QUESTION 11: WHAT IS THE PROBABILITY A VALUE WILL BE AT LEAST 20CM BELOW THE AVERAGE VALUE?
# *Probabilities calculated through built-in libraries*
# Probability of a Depth1 value being at least 20cm below the mean: 38.54 percent
# Probability of a Depth2 value being at least 20cm below the mean: 30.66 percent
